# %% [markdown]
# # DFT in Analize signalov
#
#
# ## Analiza vseh datotek iz vaje.um.si
#
# ### sig_a_1.m4a

# %%
from importlib import reload
import util
from util import *

reload(util)

MAX_SAMPLE_COUNT = 30000
MAX_FREQS_HZ = 1000

y, Fs = util.read_signal_from_m4a("/home/igor/Desktop/MAG/1_LETNIK/2_SEMESTER/RACUNALNISKA_OBDELAVA_SIGNALOV_IN_SLIK/Vaja_3/naloga_1_rpm/sig_a_1.m4a")

T = len(y) / Fs
# FIX 3 (continued): Unpack both result and freqs
y_dft, freqs = dft(y, Fs, MAX_SAMPLE_COUNT, MAX_FREQS_HZ)

# FIX 4 (continued): Pass freqs into plot
plot_analasys(y_dft, freqs, "DFT sig_a_1.m4a")

# FIX 5: Find the peak frequency from the spectrum instead of using max axis value
peak_idx = np.argmax(np.abs(y_dft))
f_blade = freqs[peak_idx]
print(f"Peak frequency: {f_blade:.2f} Hz")

calculate_rpm(f_blade, 3)
# Out:
# Peak frequency: 222.40 Hz
# Rpm: 4448.0
# np.float64(4448.0)

# %% [markdown]
# ### sig_b_1.m4a

# %%
y, Fs = util.read_signal_from_m4a("/home/igor/Desktop/MAG/1_LETNIK/2_SEMESTER/RACUNALNISKA_OBDELAVA_SIGNALOV_IN_SLIK/Vaja_3/naloga_1_rpm/sig_b_1.m4a")
T = len(y) / Fs
y_dft = np.fft.fft(y)[:MAX_FREQS_HZ]
max_freq = plot_analasys(y_dft, Fs, T, "DFT sig_a_1.m4a")

# (izhod dft, blade count)
calculate_rpm(max_freq, 3)
# Out:
# Rpm: 965.4994850669414
# 965.4994850669414

# %% [markdown]
# ### sig_c_1.m4a

# %%
y, Fs = util.read_signal_from_m4a("/home/igor/Desktop/MAG/1_LETNIK/2_SEMESTER/RACUNALNISKA_OBDELAVA_SIGNALOV_IN_SLIK/Vaja_3/naloga_1_rpm/sig_c_1.m4a")
T = len(y) / Fs
y_dft = np.fft.fft(y)[:MAX_FREQS_HZ]
max_freq = plot_analasys(y_dft, Fs, T, "DFT sig_a_1.m4a")

# (izhod dft, blade count)
calculate_rpm(max_freq, 3)
# Out:
# Rpm: 966.4958183954358
# 966.4958183954358

# %% [markdown]
# ### sig_c_2.m4a

# %%
y, Fs = util.read_signal_from_m4a("/home/igor/Desktop/MAG/1_LETNIK/2_SEMESTER/RACUNALNISKA_OBDELAVA_SIGNALOV_IN_SLIK/Vaja_3/naloga_1_rpm/sig_c_2.m4a")
T = len(y) / Fs
y_dft = np.fft.fft(y)[:MAX_FREQS_HZ]
max_freq = plot_analasys(y_dft, Fs, T, "DFT sig_a_1.m4a")

# (izhod dft, blade count)
calculate_rpm(max_freq, 3)
# Out:
# Rpm: 960.5542397963624
# 960.5542397963624
